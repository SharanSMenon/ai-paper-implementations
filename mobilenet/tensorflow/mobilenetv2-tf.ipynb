# %% [markdown]
# # MobileNet V2 in TensorFlow
#
# Based on this [paper](https://arxiv.org/pdf/1801.04381.pdf)

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers as ly
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/jax/_src/lib/__init__.py:32: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "

# %%
def bn_act(x, bn=True, act=True):
    if bn:
        x = ly.BatchNormalization(epsilon=1e-3,momentum=0.999)(x)
    if act:
        x = ly.Activation(tf.nn.relu6)(x)
    return x

# %%
def MBConv(x, n_in, n_out, expansion, ks=3, strides=1, dropout=0.1):
    skip_connection = (strides == 1)
    padding = (ks-1)//2
    if expansion != 1:
        # Expand Pointwise
        x = ly.Conv2D(expansion * n_in, kernel_size=1, padding='same', use_bias=False,
                      activation=None)(x)
        x = bn_act(x)
    ## Depthwise
    if strides == 2:
        x = ly.ZeroPadding2D(padding=padding)(x)
    x = ly.DepthwiseConv2D(kernel_size=ks, strides=strides, activation=None, use_bias=False, 
                          padding='same' if strides == 1 else 'valid')(x)
    x = bn_act(x)
    x = ly.Conv2D(n_out, (1, 1), padding='same', activation=None, use_bias=False)(x)
    x = bn_act(x, act=False)
    return x

# %%
widths = [32, 16, 24, 32, 64, 96, 160, 320, 1280]
depths = [1, 2, 3, 4, 3, 3, 1]
strides = [1, 2, 2, 2, 1, 2, 1]

# %%
def MobileNetV2(n_classes=1000):
    inputs = keras.Input(shape=(224, 224, 3))
    stem = ly.Conv2D(widths[0], (3, 3), strides=(2, 2), padding='same', use_bias=False)(inputs)
    x = bn_act(stem)
    
    for i in range(7):
        depth = depths[i]
        stride = strides[i]
        w_in = widths[i]
        w_out = widths[i + 1]
        x = MBConv(x, w_in, w_out, expansion= 1 if i == 0 else 6, strides=stride)
        for j in range(1, depth):
            x = MBConv(x, w_out, w_out, expansion= 1 if i == 0 else 6)
    
    x = ly.Conv2D(1280, kernel_size=1, use_bias=False)(x)
    x = bn_act(x)
    x = ly.GlobalAveragePooling2D()(x)
    x = ly.Dense(n_classes)(x)
    return keras.Model(inputs=inputs, outputs=x, name="mobilenetv2")

# %%
mobilenet = MobileNetV2()
# Out:
# Metal device set to: Apple M1

# %%
# %%time
mobilenet(np.random.random((1, 224, 224, 3))).shape
# Out:
# CPU times: user 96.9 ms, sys: 29 ms, total: 126 ms
# Wall time: 110 ms
# TensorShape([1, 1000])

# %%
def fmat(n):
    return "{:.2f}M".format(n / 1e6)

# %%
def params(model, f = True):
    count = int(np.sum([np.prod(p.shape) for p in model.trainable_variables]))
    return fmat(count) if f else count

# %%
print(params(mobilenet))
# Out:
# 3.50M

# %%
mobilenet.summary()
# Out:
# Model: "mobilenetv2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 112, 112, 32)      864
#
#  batch_normalization (BatchN  (None, 112, 112, 32)     128
#  ormalization)
#
#  activation (Activation)     (None, 112, 112, 32)      0
#
#  depthwise_conv2d (Depthwise  (None, 112, 112, 32)     288
#  Conv2D)
#
#  batch_normalization_1 (Batc  (None, 112, 112, 32)     128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 112, 112, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 16)      512
#
#  batch_normalization_2 (Batc  (None, 112, 112, 16)     64
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 96)      1536
#
#  batch_normalization_3 (Batc  (None, 112, 112, 96)     384
#  hNormalization)
#
#  activation_2 (Activation)   (None, 112, 112, 96)      0
#
#  zero_padding2d (ZeroPadding  (None, 114, 114, 96)     0
#  2D)
#
#  depthwise_conv2d_1 (Depthwi  (None, 56, 56, 96)       864
#  seConv2D)
#
#  batch_normalization_4 (Batc  (None, 56, 56, 96)       384
#  hNormalization)
#
#  activation_3 (Activation)   (None, 56, 56, 96)        0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 24)        2304
#
#  batch_normalization_5 (Batc  (None, 56, 56, 24)       96
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 144)       3456
#
#  batch_normalization_6 (Batc  (None, 56, 56, 144)      576
#  hNormalization)
#
#  activation_4 (Activation)   (None, 56, 56, 144)       0
#
#  depthwise_conv2d_2 (Depthwi  (None, 56, 56, 144)      1296
#  seConv2D)
#
#  batch_normalization_7 (Batc  (None, 56, 56, 144)      576
#  hNormalization)
#
#  activation_5 (Activation)   (None, 56, 56, 144)       0
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 24)        3456
#
#  batch_normalization_8 (Batc  (None, 56, 56, 24)       96
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 144)       3456
#
#  batch_normalization_9 (Batc  (None, 56, 56, 144)      576
#  hNormalization)
#
#  activation_6 (Activation)   (None, 56, 56, 144)       0
#
#  zero_padding2d_1 (ZeroPaddi  (None, 58, 58, 144)      0
#  ng2D)
#
#  depthwise_conv2d_3 (Depthwi  (None, 28, 28, 144)      1296
#  seConv2D)
#
#  batch_normalization_10 (Bat  (None, 28, 28, 144)      576
#  chNormalization)
#
#  activation_7 (Activation)   (None, 28, 28, 144)       0
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 32)        4608
#
#  batch_normalization_11 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 192)       6144
#
#  batch_normalization_12 (Bat  (None, 28, 28, 192)      768
#  chNormalization)
#
#  activation_8 (Activation)   (None, 28, 28, 192)       0
#
#  depthwise_conv2d_4 (Depthwi  (None, 28, 28, 192)      1728
#  seConv2D)
#
#  batch_normalization_13 (Bat  (None, 28, 28, 192)      768
#  chNormalization)
#
#  activation_9 (Activation)   (None, 28, 28, 192)       0
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        6144
#
#  batch_normalization_14 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 192)       6144
#
#  batch_normalization_15 (Bat  (None, 28, 28, 192)      768
#  chNormalization)
#
#  activation_10 (Activation)  (None, 28, 28, 192)       0
#
#  depthwise_conv2d_5 (Depthwi  (None, 28, 28, 192)      1728
#  seConv2D)
#
#  batch_normalization_16 (Bat  (None, 28, 28, 192)      768
#  chNormalization)
#
#  activation_11 (Activation)  (None, 28, 28, 192)       0
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 32)        6144
#
#  batch_normalization_17 (Bat  (None, 28, 28, 32)       128
#  chNormalization)
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 192)       6144
#
#  batch_normalization_18 (Bat  (None, 28, 28, 192)      768
#  chNormalization)
#
#  activation_12 (Activation)  (None, 28, 28, 192)       0
#
#  zero_padding2d_2 (ZeroPaddi  (None, 30, 30, 192)      0
#  ng2D)
#
#  depthwise_conv2d_6 (Depthwi  (None, 14, 14, 192)      1728
#  seConv2D)
#
#  batch_normalization_19 (Bat  (None, 14, 14, 192)      768
#  chNormalization)
#
#  activation_13 (Activation)  (None, 14, 14, 192)       0
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 64)        12288
#
#  batch_normalization_20 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 384)       24576
#
#  batch_normalization_21 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_14 (Activation)  (None, 14, 14, 384)       0
#
#  depthwise_conv2d_7 (Depthwi  (None, 14, 14, 384)      3456
#  seConv2D)
#
#  batch_normalization_22 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_15 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 64)        24576
#
#  batch_normalization_23 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 384)       24576
#
#  batch_normalization_24 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_16 (Activation)  (None, 14, 14, 384)       0
#
#  depthwise_conv2d_8 (Depthwi  (None, 14, 14, 384)      3456
#  seConv2D)
#
#  batch_normalization_25 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_17 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 64)        24576
#
#  batch_normalization_26 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 384)       24576
#
#  batch_normalization_27 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_18 (Activation)  (None, 14, 14, 384)       0
#
#  depthwise_conv2d_9 (Depthwi  (None, 14, 14, 384)      3456
#  seConv2D)
#
#  batch_normalization_28 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_19 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 64)        24576
#
#  batch_normalization_29 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 384)       24576
#
#  batch_normalization_30 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_20 (Activation)  (None, 14, 14, 384)       0
#
#  depthwise_conv2d_10 (Depthw  (None, 14, 14, 384)      3456
#  iseConv2D)
#
#  batch_normalization_31 (Bat  (None, 14, 14, 384)      1536
#  chNormalization)
#
#  activation_21 (Activation)  (None, 14, 14, 384)       0
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 96)        36864
#
#  batch_normalization_32 (Bat  (None, 14, 14, 96)       384
#  chNormalization)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 576)       55296
#
#  batch_normalization_33 (Bat  (None, 14, 14, 576)      2304
#  chNormalization)
#
#  activation_22 (Activation)  (None, 14, 14, 576)       0
#
#  depthwise_conv2d_11 (Depthw  (None, 14, 14, 576)      5184
#  iseConv2D)
#
#  batch_normalization_34 (Bat  (None, 14, 14, 576)      2304
#  chNormalization)
#
#  activation_23 (Activation)  (None, 14, 14, 576)       0
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 96)        55296
#
#  batch_normalization_35 (Bat  (None, 14, 14, 96)       384
#  chNormalization)
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 576)       55296
#
#  batch_normalization_36 (Bat  (None, 14, 14, 576)      2304
#  chNormalization)
#
#  activation_24 (Activation)  (None, 14, 14, 576)       0
#
#  depthwise_conv2d_12 (Depthw  (None, 14, 14, 576)      5184
#  iseConv2D)
#
#  batch_normalization_37 (Bat  (None, 14, 14, 576)      2304
#  chNormalization)
#
#  activation_25 (Activation)  (None, 14, 14, 576)       0
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 96)        55296
#
#  batch_normalization_38 (Bat  (None, 14, 14, 96)       384
#  chNormalization)
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 576)       55296
#
#  batch_normalization_39 (Bat  (None, 14, 14, 576)      2304
#  chNormalization)
#
#  activation_26 (Activation)  (None, 14, 14, 576)       0
#
#  zero_padding2d_3 (ZeroPaddi  (None, 16, 16, 576)      0
#  ng2D)
#
#  depthwise_conv2d_13 (Depthw  (None, 7, 7, 576)        5184
#  iseConv2D)
#
#  batch_normalization_40 (Bat  (None, 7, 7, 576)        2304
#  chNormalization)
#
#  activation_27 (Activation)  (None, 7, 7, 576)         0
#
#  conv2d_27 (Conv2D)          (None, 7, 7, 160)         92160
#
#  batch_normalization_41 (Bat  (None, 7, 7, 160)        640
#  chNormalization)
#
#  conv2d_28 (Conv2D)          (None, 7, 7, 960)         153600
#
#  batch_normalization_42 (Bat  (None, 7, 7, 960)        3840
#  chNormalization)
#
#  activation_28 (Activation)  (None, 7, 7, 960)         0
#
#  depthwise_conv2d_14 (Depthw  (None, 7, 7, 960)        8640
#  iseConv2D)
#
#  batch_normalization_43 (Bat  (None, 7, 7, 960)        3840
#  chNormalization)
#
#  activation_29 (Activation)  (None, 7, 7, 960)         0
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 160)         153600
#
#  batch_normalization_44 (Bat  (None, 7, 7, 160)        640
#  chNormalization)
#
#  conv2d_30 (Conv2D)          (None, 7, 7, 960)         153600
#
#  batch_normalization_45 (Bat  (None, 7, 7, 960)        3840
#  chNormalization)
#
#  activation_30 (Activation)  (None, 7, 7, 960)         0
#
#  depthwise_conv2d_15 (Depthw  (None, 7, 7, 960)        8640
#  iseConv2D)
#
#  batch_normalization_46 (Bat  (None, 7, 7, 960)        3840
#  chNormalization)
#
#  activation_31 (Activation)  (None, 7, 7, 960)         0
#
#  conv2d_31 (Conv2D)          (None, 7, 7, 160)         153600
#
#  batch_normalization_47 (Bat  (None, 7, 7, 160)        640
#  chNormalization)
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 960)         153600
#
#  batch_normalization_48 (Bat  (None, 7, 7, 960)        3840
#  chNormalization)
#
#  activation_32 (Activation)  (None, 7, 7, 960)         0
#
#  depthwise_conv2d_16 (Depthw  (None, 7, 7, 960)        8640
#  iseConv2D)
#
#  batch_normalization_49 (Bat  (None, 7, 7, 960)        3840
#  chNormalization)
#
#  activation_33 (Activation)  (None, 7, 7, 960)         0
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 320)         307200
#
#  batch_normalization_50 (Bat  (None, 7, 7, 320)        1280
#  chNormalization)
#
#  conv2d_34 (Conv2D)          (None, 7, 7, 1280)        409600
#
#  batch_normalization_51 (Bat  (None, 7, 7, 1280)       5120
#  chNormalization)
#
#  activation_34 (Activation)  (None, 7, 7, 1280)        0
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)              1281000
#
# =================================================================
# Total params: 3,538,984
# Trainable params: 3,504,872
# Non-trainable params: 34,112
# _________________________________________________________________
